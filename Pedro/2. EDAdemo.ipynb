# %% [markdown]
# # Exploring Data with Pandas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import pandas as pd
df = pd.read_csv("2. telco.csv")

# %% [markdown]
# # Display Values

# %%
df.head()
# Out:
#    Unnamed: 0  tenure  Partner  Dependents  gender  PhoneService  \
# 0           0       1        1           0       0             0
# 1           1      34        0           0       1             1
# 2           2       2        0           0       1             1
# 3           3      45        0           0       1             0
# 4           4       2        0           0       0             1
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  \
# 0                 1           29.85         29.85
# 1                 0           56.95       1889.50
# 2                 1           53.85        108.15
# 3                 0           42.30       1840.75
# 4                 1           70.70        151.65
#
#    MultipleLines_No phone service  ...  StreamingTV_No internet service  \
# 0                               1  ...                                0
# 1                               0  ...                                0
# ...

# %%
df.tail() #Showing the last 5 rows
# Out:
#       Unnamed: 0  tenure  Partner  Dependents  gender  PhoneService  \
# 7027        7038      24        1           1       1             1
# 7028        7039      72        1           1       0             1
# 7029        7040      11        1           1       0             0
# 7030        7041       4        1           0       1             1
# 7031        7042      66        0           0       1             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  \
# 7027                 1           84.80       1990.50
# 7028                 1          103.20       7362.90
# 7029                 1           29.60        346.45
# 7030                 1           74.40        306.60
# 7031                 1          105.65       6844.50
#
#       MultipleLines_No phone service  ...  StreamingTV_No internet service  \
# 7027                               0  ...                                0
# 7028                               0  ...                                0
# ...

# %%
df.columns  #describing each of the columns name
# Out:
# Index(['Unnamed: 0', 'tenure', 'Partner', 'Dependents', 'gender',
#        'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
#        'MultipleLines_No phone service', 'MultipleLines_Yes',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No internet service', 'StreamingMovies_Yes',
#        'Contract_One year', 'Contract_Two year',
#        'PaymentMethod_Credit card (automatic)',
#        'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check',
#        'Churn'],
#       dtype='object')

# %%
df.nunique()  #taking one of each values in each column
# Out:
# Unnamed: 0                               7032
# tenure                                     72
# Partner                                     2
# Dependents                                  2
# gender                                      2
# PhoneService                                2
# PaperlessBilling                            2
# MonthlyCharges                           1584
# TotalCharges                             6530
# MultipleLines_No phone service              2
# MultipleLines_Yes                           2
# InternetService_Fiber optic                 2
# InternetService_No                          2
# OnlineSecurity_No internet service          2
# OnlineSecurity_Yes                          2
# OnlineBackup_No internet service            2
# OnlineBackup_Yes                            2
# DeviceProtection_No internet service        2
# DeviceProtection_Yes                        2
# TechSupport_No internet service             2
# ...

# %%
df['Churn'].value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
df.nlargest( 10,'TotalCharges')
# Out:
#       Unnamed: 0  tenure  Partner  Dependents  gender  PhoneService  \
# 4602        4610      72        1           0       1             1
# 4578        4586      72        1           1       0             1
# 6757        6768      72        1           1       0             1
# 5338        5347      72        1           0       1             1
# 2182        2187      71        1           0       1             1
# 6109        6118      72        0           0       1             1
# 5549        5558      72        1           1       0             1
# 2363        2368      72        1           0       0             1
# 2598        2603      72        0           0       0             1
# 2020        2025      72        1           1       0             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  \
# 4602                 1          117.80       8684.80
# 4578                 1          118.75       8672.45
# 6757                 0          117.50       8670.10
# ...

# %% [markdown]
# # Stats

# %%
df.describe()
# Out:
#         Unnamed: 0       tenure      Partner   Dependents       gender  \
# count  7032.000000  7032.000000  7032.000000  7032.000000  7032.000000
# mean   3521.562144    32.421786     0.482509     0.298493     0.504693
# std    2032.832448    24.545260     0.499729     0.457629     0.500014
# min       0.000000     1.000000     0.000000     0.000000     0.000000
# 25%    1762.750000     9.000000     0.000000     0.000000     0.000000
# 50%    3521.500000    29.000000     0.000000     0.000000     1.000000
# 75%    5282.250000    55.000000     1.000000     1.000000     1.000000
# max    7042.000000    72.000000     1.000000     1.000000     1.000000
#
#        PhoneService  PaperlessBilling  MonthlyCharges  TotalCharges  \
# count   7032.000000       7032.000000     7032.000000   7032.000000
# mean       0.903299          0.592719       64.798208   2283.300441
# std        0.295571          0.491363       30.085974   2266.771362
# ...

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#                                        Unnamed: 0    tenure   Partner  \
# Unnamed: 0                               1.000000  0.006801  0.000162
# tenure                                   0.006801  1.000000  0.381912
# Partner                                  0.000162  0.381912  1.000000
# Dependents                              -0.004762  0.163386  0.452269
# gender                                  -0.008463  0.005285 -0.001379
# PhoneService                            -0.028257  0.007877  0.018397
# PaperlessBilling                         0.002143  0.004823 -0.013957
# MonthlyCharges                          -0.012938  0.246862  0.097825
# TotalCharges                             0.001820  0.825880  0.319072
# MultipleLines_No phone service           0.028257 -0.007877 -0.018397
# MultipleLines_Yes                       -0.014715  0.332399  0.142561
# InternetService_Fiber optic             -0.009976  0.017930  0.001235
# ...

# %%
sns.heatmap(df[['MonthlyCharges', 'PaperlessBilling', 
                'MultipleLines_No phone service','MultipleLines_Yes', 
                'InternetService_Fiber optic','InternetService_No',         
                'OnlineSecurity_No internet service' , 'Churn'  ]].corr())
# Out:
# <AxesSubplot:>

# %%
df[['MonthlyCharges', 'PaperlessBilling', 
                'MultipleLines_No phone service','MultipleLines_Yes', 
                'InternetService_Fiber optic','InternetService_No',         
                'OnlineSecurity_No internet service' , 'Churn'  ]].corr()
# Out:
#                                     MonthlyCharges  PaperlessBilling  \
# MonthlyCharges                            1.000000          0.351930
# PaperlessBilling                          0.351930          1.000000
# MultipleLines_No phone service           -0.248033         -0.016696
# MultipleLines_Yes                         0.490912          0.163746
# InternetService_Fiber optic               0.787195          0.326470
# InternetService_No                       -0.763191         -0.320592
# OnlineSecurity_No internet service       -0.763191         -0.320592
# Churn                                     0.192858          0.191454
#
#                                     MultipleLines_No phone service  \
# MonthlyCharges                                           -0.248033
# PaperlessBilling                                         -0.016696
# MultipleLines_No phone service                            1.000000
# MultipleLines_Yes                                        -0.279530
# ...
